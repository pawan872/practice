# %% [markdown]
# <a href="https://colab.research.google.com/github/pawan872/practice/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/pawan872/practice.git
# Out:
# Cloning into 'practice'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/spotify_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14081 entries, 0 to 14080
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        14081 non-null  int64
#  1   artist_name       14081 non-null  object
#  2   track_name        14081 non-null  object
#  3   track_id          14081 non-null  object
#  4   popularity        14080 non-null  float64
#  5   year              14080 non-null  float64
#  6   genre             14080 non-null  object
#  7   danceability      14080 non-null  float64
#  8   energy            14080 non-null  float64
#  9   key               14080 non-null  float64
#  10  loudness          14080 non-null  float64
#  11  mode              14080 non-null  float64
#  12  speechiness       14080 non-null  float64
#  13  acousticness      14080 non-null  float64
#  14  instrumentalness  14080 non-null  float64
#  15  liveness          14080 non-null  float64
# ...

# %% [markdown]
# important:
# artist name
# track name
# popularity

# %%
df
# Out:
#        Unnamed: 0             artist_name  \
# 0               0              Jason Mraz
# 1               1              Jason Mraz
# 2               2           Joshua Hyslop
# 3               3            Boyce Avenue
# 4               4            Andrew Belle
# ...           ...                     ...
# 14076       14076               Eluveitie
# 14077       14077        August Burns Red
# 14078       14078      Infant Annihilator
# 14079       14079       The Contortionist
# 14080       14080  Becoming The Archetype
#
#                                      track_name                track_id  \
# 0                               I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1                              93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2                              Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3                                      Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4                              Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
# ...
